# %% [markdown]
# # DICE 2013R (Rocky Road flavour)
#
# This notebook compares DICE.jl to the `DICE2013_032813.gms` GAMS file and Includes directory.

# %%
# For Solving #
using DICE;

# For Comparing with GAMS data
using NBInclude;
@nbinclude("../GAMS/GAMS_Compare.ipynb")

# For Additional Plots
# using Plots

version = v2013R(RockyRoad)
# Out:
# v2013R (Rocky Road flavour)

# %% [markdown]
# ## Base Price Scenario
#
# Similar to the Vanilla version of 2013R, a base and optimal price scenario exist.
#
# We will quickly compare them, as they should mimic the Vanilla version.

# %%
base = solve(BasePrice, version)
# Out:
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     3834
# Number of nonzeros in inequality constraint Jacobian.:      177
# Number of nonzeros in Lagrangian Hessian.............:     1437
#
# Total number of variables............................:     1561
#                      variables with only lower bounds:      540
#                 variables with lower and upper bounds:      180
#                      variables with only upper bounds:       60
# Total number of equality constraints.................:     1391
# Total number of inequality constraints...............:       59
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       59
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -0.0000000e+00 9.00e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
#  250 -5.8904093e+08 9.50e+04 1.00e+00  -8.6 3.92e+09 -11.5 3.98e-08 9.13e-11f 10
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
#
# Number of Iterations....: 456
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -5.8899726889549589e+08   -5.8899726889549589e+08
# Dual infeasibility......:   9.9999999777272786e-01    9.9999999777272786e-01
# Constraint violation....:   9.4998613200162436e-04    9.4998613200162436e+04
# Complementarity.........:   9.0909090935803622e-10    9.0909090935803622e-10
# Overall NLP error.......:   9.9999999777272786e-01    9.4998613200162436e+04
#
#
# Number of objective function evaluations             = 1741
# Number of objective gradient evaluations             = 200
# Number of equality constraint evaluations            = 1878
# Number of inequality constraint evaluations          = 1717
# Number of equality constraint Jacobian evaluations   = 485
# Number of inequality constraint Jacobian evaluations = 485
# Number of Lagrangian Hessian evaluations             = 457
# Total CPU secs in IPOPT (w/o function evaluations)   =    425.870
# Total CPU secs in NLP function evaluations           =      1.487
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     3834
# Number of nonzeros in inequality constraint Jacobian.:      177
# Number of nonzeros in Lagrangian Hessian.............:     1437
#
# Total number of variables............................:     1561
#                      variables with only lower bounds:      540
#                 variables with lower and upper bounds:      180
#                      variables with only upper bounds:      105
# Total number of equality constraints.................:     1391
# Total number of inequality constraints...............:       59
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       59
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -0.0000000e+00 9.00e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#  250 -2.6681158e+03 8.67e+01 1.10e-01  -2.5 4.25e+03 -17.0 1.00e+00 5.76e-01h  1
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
#  500r-8.4094309e+10 1.36e+07 5.13e+01  -9.0 4.81e+01  -7.9 1.57e-01 3.91e-08f 22
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: SOC step rejected due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Evaluation error during soft restoration phase step.
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
# The equality constraints contain an invalid number
# Warning: Cutting back alpha due to evaluation error
#
# Number of Iterations....: 694
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -8.4093690416509232e+10   -8.4093690416509232e+10
# Dual infeasibility......:   9.9999999777301052e-01    9.9999999777301052e-01
# Constraint violation....:   1.3563619823054540e-01    1.3563619823054539e+07
# Complementarity.........:   9.0909090909388540e-10    9.0909090909388540e-10
# Overall NLP error.......:   9.9999999777301052e-01    1.3563619823054539e+07
#
#
# Number of objective function evaluations             = 6547
# Number of objective gradient evaluations             = 272
# Number of equality constraint evaluations            = 6757
# Number of inequality constraint evaluations          = 6540
# Number of equality constraint Jacobian evaluations   = 708
# Number of inequality constraint Jacobian evaluations = 708
# Number of Lagrangian Hessian evaluations             = 695
# Total CPU secs in IPOPT (w/o function evaluations)   =    639.002
# Total CPU secs in NLP function evaluations           =      4.089
#
# EXIT: Converged to a point of local infeasibility. Problem may be infeasible.
# Base (current policy) carbon price scenario using v2013R (Rocky Road flavour).
# A JuMP Model
# Maximization problem with:
# Variables: 1561
# Objective function type: Nonlinear
# `JuMP.VariableRef`-in-`MathOptInterface.GreaterThan{Float64}`: 720 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.LessThan{Float64}`: 300 constraints
# `JuMP.GenericAffExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.EqualTo{Float64}`: 120 constraints
# Nonlinear: 1330 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: ATTACHED_OPTIMIZER
# Solver name: SolverName() attribute not implemented by the optimizer.
# Names registered in the model: C, CCA, CEMUTOTPER, CPC, CPRICE, DAMAGES, E, Eind, FORC, I, K, MCABATE, Mᵤₚ, Mₐₜ, Mₗₒ, PERIODU, RI, S, Tₐₜ, Tₗₒ, UTILITY, Y, YGROSS, YNET, Λ, Ω, μ

# %%
params = loadGAMSResults(version, BasePrice);

# %%
plotComparison(base, params)

# %% [markdown]
# CONOPT Utility = `2668.2118865871`

# %%
base.results.UTILITY

# %% [markdown]
# # Optimal Price Scenario

# %%
opt = solve(OptimalPrice, version)
# Out:
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     3834
# Number of nonzeros in inequality constraint Jacobian.:      177
# Number of nonzeros in Lagrangian Hessian.............:     1437
#
# Total number of variables............................:     1561
#                      variables with only lower bounds:      540
#                 variables with lower and upper bounds:      180
#                      variables with only upper bounds:       60
# Total number of equality constraints.................:     1391
# Total number of inequality constraints...............:       59
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       59
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -0.0000000e+00 9.00e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 103
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -2.7412318405178098e+03   -2.7412318405178098e+03
# Dual infeasibility......:   1.9685343644067555e-13    1.9685343644067555e-13
# Constraint violation....:   4.7761281943281553e-09    4.7761281943281553e-09
# Complementarity.........:   2.5059043145663172e-09    2.5059043145663172e-09
# Overall NLP error.......:   4.7761281943281553e-09    4.7761281943281553e-09
#
#
# Number of objective function evaluations             = 165
# Number of objective gradient evaluations             = 95
# Number of equality constraint evaluations            = 165
# Number of inequality constraint evaluations          = 165
# Number of equality constraint Jacobian evaluations   = 105
# Number of inequality constraint Jacobian evaluations = 105
# Number of Lagrangian Hessian evaluations             = 103
# Total CPU secs in IPOPT (w/o function evaluations)   =     89.189
# Total CPU secs in NLP function evaluations           =      0.272
#
# EXIT: Optimal Solution Found.
# Optimal carbon price scenario using v2013R (Rocky Road flavour).
# A JuMP Model
# Maximization problem with:
# Variables: 1561
# Objective function type: Nonlinear
# `JuMP.VariableRef`-in-`MathOptInterface.GreaterThan{Float64}`: 720 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.LessThan{Float64}`: 300 constraints
# `JuMP.GenericAffExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.EqualTo{Float64}`: 120 constraints
# Nonlinear: 1330 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: ATTACHED_OPTIMIZER
# Solver name: SolverName() attribute not implemented by the optimizer.
# Names registered in the model: C, CCA, CEMUTOTPER, CPC, CPRICE, DAMAGES, E, Eind, FORC, I, K, MCABATE, Mᵤₚ, Mₐₜ, Mₗₒ, PERIODU, RI, S, Tₐₜ, Tₗₒ, UTILITY, Y, YGROSS, YNET, Λ, Ω, μ

# %%
oparams = loadGAMSResults(version, OptimalPrice);

# %%
plotComparison(opt, oparams)

# %% [markdown]
# CONOPT Utility = `2741.2318406380`

# %%
opt.results.UTILITY
# Out:
# 2741.23184051781

# %% [markdown]
# # Limit 2 Degrees Scenario
#
# From here, we are getting into the more unique scenarios of the Rocky Road version, but their analysis needs to be no different.

# %%
# This one spools forever currently. Not advisable to run this section at the moment.
#lim2 = solve(Limit2Degrees, version)

# %%
l2params = loadGAMSResults(version, Limit2Degrees);

# %%
plotComparison(lim2, l2params)

# %% [markdown]
# # Stern Scenario

# %%
stern = solve(Stern, version)
# Out:
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     3834
# Number of nonzeros in inequality constraint Jacobian.:      177
# Number of nonzeros in Lagrangian Hessian.............:     1437
#
# Total number of variables............................:     1561
#                      variables with only lower bounds:      540
#                 variables with lower and upper bounds:      180
#                      variables with only upper bounds:       60
# Total number of equality constraints.................:     1391
# Total number of inequality constraints...............:       59
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       59
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -0.0000000e+00 9.00e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 107
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -1.2430560255441966e+05   -1.2430560255441966e+05
# Dual infeasibility......:   1.4327290686382388e-07    1.4327290686382388e-07
# Constraint violation....:   1.8189894035458565e-12    2.2358426576829513e-07
# Complementarity.........:   1.1427449449086467e-09    1.1427449449086467e-09
# Overall NLP error.......:   1.1427449449086467e-09    2.2358426576829513e-07
#
#
# Number of objective function evaluations             = 140
# Number of objective gradient evaluations             = 94
# Number of equality constraint evaluations            = 140
# Number of inequality constraint evaluations          = 140
# Number of equality constraint Jacobian evaluations   = 112
# Number of inequality constraint Jacobian evaluations = 112
# Number of Lagrangian Hessian evaluations             = 107
# Total CPU secs in IPOPT (w/o function evaluations)   =    105.043
# Total CPU secs in NLP function evaluations           =      0.239
#
# EXIT: Optimal Solution Found.
# Stern scenario using v2013R (Rocky Road flavour).
# A JuMP Model
# Maximization problem with:
# Variables: 1561
# Objective function type: Nonlinear
# `JuMP.VariableRef`-in-`MathOptInterface.GreaterThan{Float64}`: 720 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.LessThan{Float64}`: 300 constraints
# `JuMP.GenericAffExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.EqualTo{Float64}`: 120 constraints
# Nonlinear: 1330 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: ATTACHED_OPTIMIZER
# Solver name: SolverName() attribute not implemented by the optimizer.
# Names registered in the model: C, CCA, CEMUTOTPER, CPC, CPRICE, DAMAGES, E, Eind, FORC, I, K, MCABATE, Mᵤₚ, Mₐₜ, Mₗₒ, PERIODU, RI, S, Tₐₜ, Tₗₒ, UTILITY, Y, YGROSS, YNET, Λ, Ω, μ

# %%
sparams = loadGAMSResults(version, Stern);

# %%
plotComparison(stern, sparams)
# Out:
# ┌ Warning: No strict ticks found
# └ @ PlotUtils /home/tim/.julia/packages/PlotUtils/35TGG/src/ticks.jl:173
# ┌ Warning: No strict ticks found
# └ @ PlotUtils /home/tim/.julia/packages/PlotUtils/35TGG/src/ticks.jl:173
# ┌ Warning: No strict ticks found
# └ @ PlotUtils /home/tim/.julia/packages/PlotUtils/35TGG/src/ticks.jl:173
# ┌ Warning: No strict ticks found
# └ @ PlotUtils /home/tim/.julia/packages/PlotUtils/35TGG/src/ticks.jl:173

# %% [markdown]
# # Stern Calibrated Scenario
#
# This one is wonky atm, so we will look at it last.

# %%
#sterncal = solve(SternCalibrated, version)

# %%
scparams = loadGAMSResults(version, SternCalibrated);

# %%
plotComparison(sterncal, scparams)

# %% [markdown]
# # Copenhagen Scenario

# %%
cop = solve(Copenhagen, version)
# Out:
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     3594
# Number of nonzeros in inequality constraint Jacobian.:      177
# Number of nonzeros in Lagrangian Hessian.............:     1077
#
# Total number of variables............................:     1501
#                      variables with only lower bounds:      540
#                 variables with lower and upper bounds:      120
#                      variables with only upper bounds:       60
# Total number of equality constraints.................:     1391
# Total number of inequality constraints...............:       59
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       59
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -0.0000000e+00 9.00e+03 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 165
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -2.7254158209963612e+03   -2.7254158209963612e+03
# Dual infeasibility......:   1.1368683772161603e-13    1.1368683772161603e-13
# Constraint violation....:   1.8189894035458565e-12    1.8189894035458565e-12
# Complementarity.........:   9.0909094973923948e-10    9.0909094973923948e-10
# Overall NLP error.......:   9.0909094973923948e-10    9.0909094973923948e-10
#
#
# Number of objective function evaluations             = 168
# Number of objective gradient evaluations             = 76
# Number of equality constraint evaluations            = 168
# Number of inequality constraint evaluations          = 168
# Number of equality constraint Jacobian evaluations   = 167
# Number of inequality constraint Jacobian evaluations = 167
# Number of Lagrangian Hessian evaluations             = 165
# Total CPU secs in IPOPT (w/o function evaluations)   =    206.014
# Total CPU secs in NLP function evaluations           =      0.338
#
# EXIT: Optimal Solution Found.
# Copenhagen participation scenario using v2013R (Rocky Road flavour).
# A JuMP Model
# Maximization problem with:
# Variables: 1561
# Objective function type: Nonlinear
# `JuMP.VariableRef`-in-`MathOptInterface.EqualTo{Float64}`: 60 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.GreaterThan{Float64}`: 660 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.LessThan{Float64}`: 240 constraints
# `JuMP.GenericAffExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.EqualTo{Float64}`: 120 constraints
# Nonlinear: 1330 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: ATTACHED_OPTIMIZER
# Solver name: SolverName() attribute not implemented by the optimizer.
# Names registered in the model: C, CCA, CEMUTOTPER, CPC, CPRICE, DAMAGES, E, Eind, FORC, I, K, MCABATE, Mᵤₚ, Mₐₜ, Mₗₒ, PERIODU, RI, S, Tₐₜ, Tₗₒ, UTILITY, Y, YGROSS, YNET, Λ, Ω, μ

# %%
copparams = loadGAMSResults(version, Copenhagen);

# %%
plotComparison(cop, copparams)
