# %% [markdown]
# # DICE 2016R2
#
# This notebook compares DICE.jl to the `DICE2016R2-Unc-{base|opt}-v5-55555-083017B.gms` GAMS files, taking the 'DICE best guess' parameters as default.

# %%
# For Solving #
using DICE;

# For Comparing with GAMS data
using NBInclude;
@nbinclude("../GAMS/GAMS_Compare.ipynb")

# For Additional Plots
using Plots

version = v2016R2()
# Out:
# v2016R2

# %% [markdown]
# ## Base Price Scenario
#
# The 2016R2 version has a base carbon price and an optimal carbon price scenario.
#
# If you are interested in just the preset scenarios there is no reason to generate a configuration struct by calling `options(v2016R2())`, since this is called internally and altered as needed if necessary.
#
# Calling the solve function directly is all that's needed to obtain all results.

# %%
base = solve(BasePrice, version)
# Out:
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     6757
# Number of nonzeros in inequality constraint Jacobian.:      297
# Number of nonzeros in Lagrangian Hessian.............:     1586
#
# Total number of variables............................:     2686
#                      variables with only lower bounds:      897
#                 variables with lower and upper bounds:      299
#                      variables with only upper bounds:      199
# Total number of equality constraints.................:     2396
# Total number of inequality constraints...............:       99
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       99
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -0.0000000e+00 1.10e+04 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 96
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.6202953907441070e+03   -4.6202953907441070e+03
# Dual infeasibility......:   1.1368683772161603e-13    1.1368683772161603e-13
# Constraint violation....:   4.5994305031271665e-09    4.5994305031271665e-09
# Complementarity.........:   2.5059036233659280e-09    2.5059036233659280e-09
# Overall NLP error.......:   4.5994305031271665e-09    4.5994305031271665e-09
#
#
# Number of objective function evaluations             = 125
# Number of objective gradient evaluations             = 92
# Number of equality constraint evaluations            = 125
# Number of inequality constraint evaluations          = 125
# Number of equality constraint Jacobian evaluations   = 98
# Number of inequality constraint Jacobian evaluations = 98
# Number of Lagrangian Hessian evaluations             = 96
# Total CPU secs in IPOPT (w/o function evaluations)   =    179.423
# Total CPU secs in NLP function evaluations           =      1.342
#
# EXIT: Optimal Solution Found.
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     6757
# Number of nonzeros in inequality constraint Jacobian.:      297
# Number of nonzeros in Lagrangian Hessian.............:     1586
#
# Total number of variables............................:     2686
#                      variables with only lower bounds:      897
#                 variables with lower and upper bounds:      299
#                      variables with only upper bounds:      199
# Total number of equality constraints.................:     2396
# Total number of inequality constraints...............:       99
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       99
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -0.0000000e+00 1.10e+04 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 125
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.4892335489507277e+03   -4.4892335489507277e+03
# Dual infeasibility......:   1.1368683772161603e-13    1.1368683772161603e-13
# Constraint violation....:   1.8189894035458565e-12    8.0436036387077081e-08
# Complementarity.........:   2.5059035732371740e-09    2.5059035732371740e-09
# Overall NLP error.......:   2.5059035732371740e-09    8.0436036387077081e-08
#
#
# Number of objective function evaluations             = 176
# Number of objective gradient evaluations             = 124
# Number of equality constraint evaluations            = 176
# Number of inequality constraint evaluations          = 176
# Number of equality constraint Jacobian evaluations   = 127
# Number of inequality constraint Jacobian evaluations = 127
# Number of Lagrangian Hessian evaluations             = 125
# Total CPU secs in IPOPT (w/o function evaluations)   =     71.797
# Total CPU secs in NLP function evaluations           =      0.150
#
# EXIT: Optimal Solution Found.
# Base (current policy) carbon price scenario using v2016R2.
# A JuMP Model
# Maximization problem with:
# Variables: 2701
# Objective function type: JuMP.VariableRef
# `JuMP.GenericAffExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.EqualTo{Float64}`: 1196 constraints
# `JuMP.GenericAffExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.LessThan{Float64}`: 99 constraints
# `JuMP.GenericQuadExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.EqualTo{Float64}`: 400 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.EqualTo{Float64}`: 15 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.GreaterThan{Float64}`: 1196 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.LessThan{Float64}`: 498 constraints
# Nonlinear: 800 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: ATTACHED_OPTIMIZER
# Solver name: Ipopt
# Names registered in the model: C, CCA, CCATOT, CEMUTOTPER, CPC, CPRICE, DAMAGES, E, Eind, FORC, I, K, MCABATE, Mᵤₚ, Mₐₜ, Mₗₒ, PERIODU, RI, S, Tₐₜ, Tₗₒ, UTILITY, Y, YGROSS, YNET, Λ, Ω, μ

# %% [markdown]
# The variable `base` is now a complete solution of type `DICENarrative`.
#
# It contains all of the model parameters and information, as well as usable results.

# %%
fieldnames(typeof(base))
# Out:
# (:constants, :parameters, :model, :scenario, :version, :variables, :equations, :results)

# %% [markdown]
# Whilst the `results` are fairly comprehensive, you may wish to look at specific values of the model directly. Since most of these are in their raw state you will need to `import JuMP` to read them correctly.
#
# ---
#
# Word of warning: if you `print(base.model)` in this notebook you're gonna have a bad time.
# It's apparently too big to print or something.
# The thread just locks up/spools forever.
#
# There's a *limit output* notebook extension which can truncate things for you.
# It seems to be necessary if you want to use notebooks which have actual output.

# %%
# Plot major outputs #
r = base.results;
a = plot(r.years,r.scc, ylabel="\$ (trillion)", title="SCC")
b = plot(r.years,r.Tₐₜ, ylabel="°C/T0", title="Atmos Temp")
c = plot(r.years,r.FORC, xlabel="Years", ylabel="Wm^(-2)/T_0", title="Forcing")
d = plot(r.years,r.Tₗₒ, xlabel="Years", ylabel="°C/T0", title="Low Ocean Temp")
plot(a,b,c,d,layout=(2,2),legend=false)

# %% [markdown]
# # Optimal Scenario
#
# The optimal carbon price scenario is ran in a similar fashion.

# %%
opt = solve(OptimalPrice, version)
# Out:
# This is Ipopt version 3.12.13, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     6753
# Number of nonzeros in inequality constraint Jacobian.:      297
# Number of nonzeros in Lagrangian Hessian.............:     1581
#
# Total number of variables............................:     2685
#                      variables with only lower bounds:      897
#                 variables with lower and upper bounds:      298
#                      variables with only upper bounds:       99
# Total number of equality constraints.................:     2396
# Total number of inequality constraints...............:       99
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       99
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -0.0000000e+00 1.10e+04 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#
# Number of Iterations....: 171
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -4.5180391988046940e+03   -4.5180391988046940e+03
# Dual infeasibility......:   2.2737367544323206e-13    2.2737367544323206e-13
# Constraint violation....:   2.4782200735984361e-09    2.4782200735984361e-09
# Complementarity.........:   2.5059036211710241e-09    2.5059036211710241e-09
# Overall NLP error.......:   2.5059036211710241e-09    2.5059036211710241e-09
#
#
# Number of objective function evaluations             = 184
# Number of objective gradient evaluations             = 170
# Number of equality constraint evaluations            = 184
# Number of inequality constraint evaluations          = 184
# Number of equality constraint Jacobian evaluations   = 173
# Number of inequality constraint Jacobian evaluations = 173
# Number of Lagrangian Hessian evaluations             = 171
# Total CPU secs in IPOPT (w/o function evaluations)   =    110.206
# Total CPU secs in NLP function evaluations           =      0.193
#
# EXIT: Optimal Solution Found.
# Optimal carbon price scenario using v2016R2.
# A JuMP Model
# Maximization problem with:
# Variables: 2701
# Objective function type: JuMP.VariableRef
# `JuMP.GenericAffExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.EqualTo{Float64}`: 1196 constraints
# `JuMP.GenericAffExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.LessThan{Float64}`: 99 constraints
# `JuMP.GenericQuadExpr{Float64,JuMP.VariableRef}`-in-`MathOptInterface.EqualTo{Float64}`: 400 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.EqualTo{Float64}`: 16 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.GreaterThan{Float64}`: 1195 constraints
# `JuMP.VariableRef`-in-`MathOptInterface.LessThan{Float64}`: 497 constraints
# Nonlinear: 800 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: ATTACHED_OPTIMIZER
# Solver name: Ipopt
# Names registered in the model: C, CCA, CCATOT, CEMUTOTPER, CPC, CPRICE, DAMAGES, E, Eind, FORC, I, K, MCABATE, Mᵤₚ, Mₐₜ, Mₗₒ, PERIODU, RI, S, Tₐₜ, Tₗₒ, UTILITY, Y, YGROSS, YNET, Λ, Ω, μ

# %%
# Plot major outputs #
ro = opt.results;
a = plot(ro.years,ro.scc, ylabel="\$ (trillion)", title="SCC")
b = plot(ro.years,ro.Tₐₜ, ylabel="°C/T0", title="Atmos Temp")
c = plot(ro.years,ro.FORC, xlabel="Years", ylabel="Wm^(-2)/T_0", title="Forcing")
d = plot(ro.years,ro.Tₗₒ, xlabel="Years", ylabel="°C/T0", title="Low Ocean Temp")
plot(a,b,c,d,layout=(2,2),legend=false)

# %% [markdown]
# # Base Price Comparison

# %%
params = loadGAMSResults(version, BasePrice);

# %%
plotComparison(base, params)

# %% [markdown]
# CONOPT Utility = `4485.6767040826`

# %%
base.results.UTILITY
# Out:
# 4489.233548950728

# %% [markdown]
# # Optimal Price Comparison

# %%
oparams = loadGAMSResults(version, OptimalPrice);

# %%
plotComparison(opt, oparams)

# %% [markdown]
# CONOPT Utility = `4515.8311036492`

# %%
opt.results.UTILITY
# Out:
# 4518.039198804694
